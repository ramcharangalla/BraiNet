# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

import os

# %% [markdown]
# Based on the paper (The one in the code directory, "Signal Acquisition" section) channel oz is the best to identify users

# %%
DATA_DIR = 'dataset'
channel = 'Oz..'
dataSets = []
for fil in os.listdir(DATA_DIR):
    if fil.endswith('.csv'):
        datafile = pd.read_csv(os.path.join(DATA_DIR, fil))
        userId = fil[2:4]
        datafile['userId'] = userId
        dataSets.append(datafile)
data = pd.concat(dataSets)

# %%
#Ensemble Averaging
#The aim is to average the results of the 50 samples to smooth out the data. We can use a sliding window to smooth the data
averagingWindow = 50
for user in data.userId.unique():
    data.loc[data.userId == user] = pd.rolling_mean(data[data.userId == user], averagingWindow, center=False, min_periods=0)
# Out:
# /Users/shashankbhushan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(min_periods=0,window=50,center=False).mean()
#   """

# %%
#Starting with frequency analysis and feature generation
#We will use 1 of data for checking user identity, with feautures created by 500 ms of data. Each such sample
#will be of length 15. There will be 80 samples in a second as frequency is 160 and we are taking 500 ms as the sample
#size, so if we slide a window of 80 i.e. 500 ms we should get 80 samples in a second

'''
Things to do:
1. split the data for a user into 500 ms samples
2. convert to fft and pass the low pass 60hz filter
3. Split the data in the 5 bands and calculate the mean, std and entropy
'''

featureOrder = ['delta_mean', 'delta_std', 'delta_entropy', 'theta_mean', 'theta_std', 'theta_entropy',
                'alpha_mean', 'alpha_std', 'alpha_entropy',
               'beta_mean', 'beta_std', 'beta_entropy', 'gamma_mean', 'gamma_std', 'gamma_entropy',]
def fftFeatureTransformation(windowData):
    #Calculating the FFT features
    Fs = 160.0
    y = windowData
    n = y.shape[0]
    k = np.arange(n)
    T = n/Fs
    frq = k/T # two sides frequency range
    frq = frq[range(n/2)] # one side frequency range

    Y = np.fft.fft(y)/n # fft computing and normalization
    Y = Y[range(n/2)]
    
    #using a low pass filter to filter out frequency above 60 hz
    Y = abs(Y[frq <= 60])
    frq = frq[frq <= 60]
    
    lowerBandEnd = 0
    bandSteps = [4, 8, 15, 30, 60]
    featureData = []
    for upperBand in bandSteps:
        bandData = Y[(frq >= lowerBandEnd) & (frq <= upperBand)]
        #calculating the mean of the band data
        featureData.append(bandData.mean())
        
        #calculating the std of the band data
        featureData.append(bandData.std())
        
        featureData.append( -1*(np.dot(np.square(bandData), np.log(np.square(bandData)))).sum() )
    return featureData

def createFeatures(df, le):
    dataSet = []
    df = df.reset_index(drop=True)
    for i in range(le): #1600 - 160):
        dataWindow = df.loc[i - 80: i]
        #print dataWindow.shape
        dataSet.append(fftFeatureTransformation(dataWindow))
    return dataSet

# %%
# Taking 1 second of data
#ozChannelData_u1 = ensembleAverage_user1[channel].reset_index(drop=True)[160:1600]
#ozChannelData_u2 = ensembleAverage_user2[channel].reset_index(drop=True)[160:1600]

transformedDataSets = []
for user in data.userId.unique():
    channelData = data[data.userId == user][channel].reset_index(drop=True)[160:]
    transformedDataset_user = pd.DataFrame(createFeatures(channelData, channelData.shape[0] - 160), columns = featureOrder)
    transformedDataset_user['userId'] = user
    transformedDataSets.append(transformedDataset_user)

transformedData = pd.concat(transformedDataSets)
# Out:
# /Users/shashankbhushan/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:39: RuntimeWarning: Mean of empty slice.

# %%
'''
Need to now run the 2 experiments to determine which model to pick and deploy
'''

from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %%
'''
Experiment 1:
Accept the correct user
1. Randomly sample 80 points from the dataset for the same user. And check if the algorithm works or not
2. Perform it for all the users
'''
#[('Random Forest', RandomForestClassifier(max_depth = 3))] Did not perform well in identifying same user
mdls = [('Linear SVM', LinearSVC(C = 0.01)), ('Logistic Regression', LogisticRegression(C = 0.01)), ('Naive Bayes', GaussianNB())] #, 
for user in transformedData.userId.unique():
    print 'Running for user', user
    mdlResults = {}
    for i in range(100):
        x = transformedData[transformedData.userId == user].reset_index(drop=True).loc[1:].sample(80) #.iloc[1:161]
        y = [1]*(x.shape[0]/2) + [0]*(x.shape[0]/2)
        for mdlName, mdl in mdls:
            mdl.fit(x, y)
            pred_y = mdl.predict(x)
            #print 'For Model', mdlName, 'the accuracy was', (pred_y == y).mean()
            mdlResults[mdlName] = mdlResults.get(mdlName, []) + [(pred_y == y).mean()]
        #print '-'*53
    for mdl in mdlResults.keys():
        print 'Average accuracy or model', mdl, 'is', np.array(mdlResults[mdl]).mean()
    print '**'*53
# Out:
# Running for user 1
# Average accuracy or model Naive Bayes is 0.528125
# Average accuracy or model Linear SVM is 0.520875
# Average accuracy or model Logistic Regression is 0.580625
# **********************************************************************************************************
# Running for user 2
# Average accuracy or model Naive Bayes is 0.5295
# Average accuracy or model Linear SVM is 0.548875
# Average accuracy or model Logistic Regression is 0.55975
# **********************************************************************************************************
# Running for user 3
# Average accuracy or model Naive Bayes is 0.53425
# Average accuracy or model Linear SVM is 0.52275
# Average accuracy or model Logistic Regression is 0.578625
# **********************************************************************************************************
# Running for user 4
# Average accuracy or model Naive Bayes is 0.5515
# Average accuracy or model Linear SVM is 0.5385
# Average accuracy or model Logistic Regression is 0.58175
# **********************************************************************************************************
# Running for user 5
# Average accuracy or model Naive Bayes is 0.5285
# Average accuracy or model Linear SVM is 0.544125
# Average accuracy or model Logistic Regression is 0.567125
# **********************************************************************************************************
# Running for user 6
# Average accuracy or model Naive Bayes is 0.552625
# Average accuracy or model Linear SVM is 0.535
# Average accuracy or model Logistic Regression is 0.57025
# **********************************************************************************************************
# Running for user 7
# Average accuracy or model Naive Bayes is 0.54575
# Average accuracy or model Linear SVM is 0.543
# Average accuracy or model Logistic Regression is 0.574
# **********************************************************************************************************
# Running for user 8
# Average accuracy or model Naive Bayes is 0.539
# Average accuracy or model Linear SVM is 0.523875
# Average accuracy or model Logistic Regression is 0.57975
# **********************************************************************************************************
# Running for user 9
# Average accuracy or model Naive Bayes is 0.546
# Average accuracy or model Linear SVM is 0.523375
# Average accuracy or model Logistic Regression is 0.58025
# **********************************************************************************************************
# Running for user 10
# Average accuracy or model Naive Bayes is 0.54275
# Average accuracy or model Linear SVM is 0.513
# Average accuracy or model Logistic Regression is 0.594625
# **********************************************************************************************************

# %%
'''
Experiment 2:
Distinguish between 2 different users
1. Randomly sample 40 points from one user and another 40 points from another user and check if it works or not
2. Perform it for all the pairs of users
'''
mdls = [('Linear SVM', LinearSVC(C = 0.01)), ('Logistic Regression', LogisticRegression(C = 0.01)), ('Naive Bayes', GaussianNB())] #, 
users = list(transformedData.userId.unique())
for i, userA in enumerate(users):
    for userB in users[i+1:]:
        print 'Running for users', userA, userB
        mdlResults = {}
        for i in range(100):
            x_a = transformedData[transformedData.userId == userA].reset_index(drop=True).loc[1:].sample(40) #.iloc[1:161]
            x_b = transformedData[transformedData.userId == userB].reset_index(drop=True).loc[1:].sample(40)
            x = x_a.append(x_b)
            y = [1]*(x_a.shape[0]) + [0]*(x_b.shape[0])
            for mdlName, mdl in mdls:
                mdl.fit(x, y)
                pred_y = mdl.predict(x)
                #print 'For Model', mdlName, 'the accuracy was', (pred_y == y).mean()
                mdlResults[mdlName] = mdlResults.get(mdlName, []) + [(pred_y == y).mean()]
            #print '-'*53
        for mdl in mdlResults.keys():
            print 'Average accuracy or model', mdl, 'is', np.array(mdlResults[mdl]).mean()
        print '**'*53
# Out:
# Running for users 1 2
# Average accuracy or model Naive Bayes is 0.846375
# Average accuracy or model Linear SVM is 0.82875
# Average accuracy or model Logistic Regression is 0.8665
# **********************************************************************************************************
# Running for users 1 3
# Average accuracy or model Naive Bayes is 0.787
# Average accuracy or model Linear SVM is 0.57325
# Average accuracy or model Logistic Regression is 0.871375
# **********************************************************************************************************
# Running for users 1 4
# Average accuracy or model Naive Bayes is 0.917625
# Average accuracy or model Linear SVM is 0.668
# Average accuracy or model Logistic Regression is 0.878125
# **********************************************************************************************************
# Running for users 1 5
# Average accuracy or model Naive Bayes is 0.9415
# Average accuracy or model Linear SVM is 0.843375
# Average accuracy or model Logistic Regression is 0.924125
# **********************************************************************************************************
# Running for users 1 6
# Average accuracy or model Naive Bayes is 0.96575
# Average accuracy or model Linear SVM is 0.785125
# Average accuracy or model Logistic Regression is 0.940375
# **********************************************************************************************************
# Running for users 1 7
# Average accuracy or model Naive Bayes is 0.975875
# Average accuracy or model Linear SVM is 0.849
# Average accuracy or model Logistic Regression is 0.96075
# **********************************************************************************************************
# Running for users 1 8
# Average accuracy or model Naive Bayes is 0.998875
# Average accuracy or model Linear SVM is 0.7225
# Average accuracy or model Logistic Regression is 0.99125
# **********************************************************************************************************
# Running for users 1 9
# Average accuracy or model Naive Bayes is 0.999
# Average accuracy or model Linear SVM is 0.7085
# Average accuracy or model Logistic Regression is 0.99375
# **********************************************************************************************************
# Running for users 1 10
# Average accuracy or model Naive Bayes is 0.996875
# Average accuracy or model Linear SVM is 0.641125
# Average accuracy or model Logistic Regression is 0.99525
# **********************************************************************************************************
# Running for users 2 3
# Average accuracy or model Naive Bayes is 0.801125
# Average accuracy or model Linear SVM is 0.807375
# Average accuracy or model Logistic Regression is 0.84275
# **********************************************************************************************************
# Running for users 2 4
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.73075
# Average accuracy or model Logistic Regression is 0.81625
# **********************************************************************************************************
# Running for users 2 5
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.87525
# Average accuracy or model Logistic Regression is 0.823375
# **********************************************************************************************************
# Running for users 2 6
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.9185
# Average accuracy or model Logistic Regression is 0.8745
# **********************************************************************************************************
# Running for users 2 7
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.944375
# Average accuracy or model Logistic Regression is 0.921
# **********************************************************************************************************
# Running for users 2 8
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.911125
# Average accuracy or model Logistic Regression is 0.969625
# **********************************************************************************************************
# Running for users 2 9
# Average accuracy or model Naive Bayes is 0.998375
# Average accuracy or model Linear SVM is 0.928875
# Average accuracy or model Logistic Regression is 0.961375
# **********************************************************************************************************
# Running for users 2 10
# Average accuracy or model Naive Bayes is 0.989125
# Average accuracy or model Linear SVM is 0.91825
# Average accuracy or model Logistic Regression is 0.949875
# **********************************************************************************************************
# Running for users 3 4
# Average accuracy or model Naive Bayes is 0.694625
# Average accuracy or model Linear SVM is 0.604375
# Average accuracy or model Logistic Regression is 0.747875
# **********************************************************************************************************
# Running for users 3 5
# Average accuracy or model Naive Bayes is 0.84975
# Average accuracy or model Linear SVM is 0.723
# Average accuracy or model Logistic Regression is 0.8675
# **********************************************************************************************************
# Running for users 3 6
# Average accuracy or model Naive Bayes is 0.862125
# Average accuracy or model Linear SVM is 0.676375
# Average accuracy or model Logistic Regression is 0.860125
# **********************************************************************************************************
# Running for users 3 7
# Average accuracy or model Naive Bayes is 0.921125
# Average accuracy or model Linear SVM is 0.752625
# Average accuracy or model Logistic Regression is 0.895125
# **********************************************************************************************************
# Running for users 3 8
# Average accuracy or model Naive Bayes is 0.990875
# Average accuracy or model Linear SVM is 0.63625
# Average accuracy or model Logistic Regression is 0.88125
# **********************************************************************************************************
# Running for users 3 9
# Average accuracy or model Naive Bayes is 0.996875
# Average accuracy or model Linear SVM is 0.66
# Average accuracy or model Logistic Regression is 0.893125
# **********************************************************************************************************
# Running for users 3 10
# Average accuracy or model Naive Bayes is 0.99075
# Average accuracy or model Linear SVM is 0.62225
# Average accuracy or model Logistic Regression is 0.9065
# **********************************************************************************************************
# Running for users 4 5
# Average accuracy or model Naive Bayes is 0.99925
# Average accuracy or model Linear SVM is 0.616125
# Average accuracy or model Logistic Regression is 0.743
# **********************************************************************************************************
# Running for users 4 6
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.623
# Average accuracy or model Logistic Regression is 0.735875
# **********************************************************************************************************
# Running for users 4 7
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.73125
# Average accuracy or model Logistic Regression is 0.795875
# **********************************************************************************************************
# Running for users 4 8
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.640875
# Average accuracy or model Logistic Regression is 0.876375
# **********************************************************************************************************
# Running for users 4 9
# Average accuracy or model Naive Bayes is 0.994125
# Average accuracy or model Linear SVM is 0.715
# Average accuracy or model Logistic Regression is 0.893375
# **********************************************************************************************************
# Running for users 4 10
# Average accuracy or model Naive Bayes is 0.95875
# Average accuracy or model Linear SVM is 0.776125
# Average accuracy or model Logistic Regression is 0.886
# **********************************************************************************************************
# Running for users 5 6
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.570375
# Average accuracy or model Logistic Regression is 0.6005
# **********************************************************************************************************
# Running for users 5 7
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.6975
# Average accuracy or model Logistic Regression is 0.73175
# **********************************************************************************************************
# Running for users 5 8
# Average accuracy or model Naive Bayes is 0.998625
# Average accuracy or model Linear SVM is 0.741625
# Average accuracy or model Logistic Regression is 0.82075
# **********************************************************************************************************
# Running for users 5 9
# Average accuracy or model Naive Bayes is 0.955125
# Average accuracy or model Linear SVM is 0.787
# Average accuracy or model Logistic Regression is 0.865875
# **********************************************************************************************************
# Running for users 5 10
# Average accuracy or model Naive Bayes is 0.952375
# Average accuracy or model Linear SVM is 0.89425
# Average accuracy or model Logistic Regression is 0.932875
# **********************************************************************************************************
# Running for users 6 7
# Average accuracy or model Naive Bayes is 1.0
# Average accuracy or model Linear SVM is 0.606
# Average accuracy or model Logistic Regression is 0.667
# **********************************************************************************************************
# Running for users 6 8
# Average accuracy or model Naive Bayes is 0.998875
# Average accuracy or model Linear SVM is 0.658125
# Average accuracy or model Logistic Regression is 0.78075
# **********************************************************************************************************
# Running for users 6 9
# Average accuracy or model Naive Bayes is 0.913
# Average accuracy or model Linear SVM is 0.735875
# Average accuracy or model Logistic Regression is 0.8665
# **********************************************************************************************************
# Running for users 6 10
# Average accuracy or model Naive Bayes is 0.947125
# Average accuracy or model Linear SVM is 0.868125
# Average accuracy or model Logistic Regression is 0.9325
# **********************************************************************************************************
# Running for users 7 8
# Average accuracy or model Naive Bayes is 0.906
# Average accuracy or model Linear SVM is 0.668625
# Average accuracy or model Logistic Regression is 0.79325
# **********************************************************************************************************
# Running for users 7 9
# Average accuracy or model Naive Bayes is 0.871875
# Average accuracy or model Linear SVM is 0.69925
# Average accuracy or model Logistic Regression is 0.85125
# **********************************************************************************************************
# Running for users 7 10
# Average accuracy or model Naive Bayes is 0.93775
# Average accuracy or model Linear SVM is 0.8625
# Average accuracy or model Logistic Regression is 0.937125
# **********************************************************************************************************
# Running for users 8 9
# Average accuracy or model Naive Bayes is 0.68
# Average accuracy or model Linear SVM is 0.546125
# Average accuracy or model Logistic Regression is 0.654875
# **********************************************************************************************************
# Running for users 8 10
# Average accuracy or model Naive Bayes is 0.76025
# Average accuracy or model Linear SVM is 0.666625
# Average accuracy or model Logistic Regression is 0.773
# **********************************************************************************************************
# Running for users 9 10
# Average accuracy or model Naive Bayes is 0.643625
# Average accuracy or model Linear SVM is 0.581375
# Average accuracy or model Logistic Regression is 0.672375
# **********************************************************************************************************

# %%
# Out:
#       delta_mean  delta_std  delta_entropy  theta_mean  theta_std  \
# 1140    6.457475   5.651211   -1130.791623    4.401789   5.050249
# 305     5.892747   2.028969    -451.103828    4.626145   2.226444
# 119    22.705367  20.892818  -22098.782876   14.448275  19.087810
# 142    16.539879  16.528600  -11811.676968   10.654473  14.702914
# 1359    6.858732   3.644130    -805.769225    4.412985   4.118639
# 522     5.428865   2.439464    -408.144719    3.813136   2.748750
# 1174   11.578844   8.483995   -3697.349392    7.162301   8.513510
# 204     9.637350  10.044963   -3620.091771    6.035696   8.944271
# 1087    3.799880   3.595554    -336.395813    2.648018   3.122967
# 1056    3.228277   3.436164    -271.163665    2.541143   2.793818
# 243    10.400982  10.358235   -4061.775555    6.582858   9.286805
# 1339    7.506564   5.225624   -1249.976233    4.789576   5.242266
# 9      39.984000   0.000000  -11793.693378   39.984000   0.000000
# 1317    7.767205   4.674576   -1203.115367    4.891374   5.055667
# 1050    4.168740   3.010562    -314.503951    3.161794   2.639098
# 502     6.092764   4.123158    -744.950328    3.717324   4.320634
# 1312    7.753238   4.261921   -1120.448401    4.821731   4.878300
# 515     5.287376   3.767725    -532.150536    3.771285   3.460095
# 755    13.744014  12.457234   -6832.251552    8.309540  11.722205
# 85     23.347977  27.651325  -32268.416758   14.310116  24.110165
# 812    13.856518  13.555416   -7646.514316    8.663123  12.276335
# 540     4.302206   1.665954    -212.278715    2.839798   2.207608
# 876    16.666720  16.630490  -12039.699564   10.164743  15.145008
# 1114    6.050531   3.379169    -608.748294    4.182428   3.485633
# 1319    7.737289   4.836730   -1228.464769    4.946913   5.074586
# 1180   11.660982   9.101074   -3988.018680    7.366962   8.795602
# 1281    3.851363   0.642011    -127.088209    2.775693   1.410437
# 1109    5.632515   3.467555    -552.745123    3.871157   3.457442
# 418     4.613421   2.909921    -352.638432    3.006844   3.000833
# 148    15.389069  15.263335   -9951.979347   10.090488  13.487449
# ...          ...        ...            ...         ...        ...
# 390     4.394435   3.076304    -335.940123    3.097971   2.863502
# 1116    6.250297   3.287179    -634.473454    4.336335   3.464643
# 61     34.606624  27.570796  -32126.519111   18.733335  25.141083
# 470     5.668510   5.593086    -966.157592    3.814384   4.895967
# 213     9.678177  10.057407   -3641.892873    6.054161   8.966187
# 526    2.104843   -361.210227    0.810831   1.635513    -359.695167
# 337    1.778842   -222.119929    0.513969   1.356943    -221.918369
# 709    5.302415  -3815.593945    2.307531   4.128771   -3810.450308
# 758    7.557503  -6807.101361    1.395908   5.591244   -6807.055520
# 0           NaN     -0.000000         NaN        NaN      -0.000000
# 726    6.143989  -4678.476185    2.039605   4.689416   -4674.113763
# 751    7.518729  -6770.531821    1.444522   5.567882   -6770.301250
# 241    6.043031  -4163.357552    1.181658   4.468347   -4162.770535
# 1071   1.630107   -176.756778    0.389150   1.224917    -176.697190
# 675    6.131698  -4774.941358    2.017049   4.669536   -4770.459627
# 1306   3.268096   -993.083868    0.929916   2.476327    -992.191025
# 977    3.215194   -927.150977    0.862923   2.441819    -926.950301
#
# [320 rows x 15 columns]

# %%
train_x[40:].describe()
# Out:
#        delta_mean  delta_std  delta_entropy  theta_mean  theta_std  \
# count   40.000000  40.000000      40.000000   40.000000  40.000000
# mean    17.894218  16.692240  -13433.154662   11.477378  15.139405
# std      2.929637   2.028840    4287.101016    1.847977   2.023689
# min     13.871458  13.416976  -21575.595094    8.556245  12.263231
# 25%     15.250060  15.001710  -16891.024478    9.984741  13.289878
# 50%     17.427865  16.796749  -12752.414347   11.203015  15.087248
# 75%     20.665306  18.097894   -9658.254959   13.317128  16.659747
# max     22.584311  20.563811   -7645.718994   14.300013  18.891369
#
#        theta_entropy  alpha_mean  alpha_std  alpha_entropy  beta_mean  \
# count      40.000000   40.000000  40.000000      40.000000  40.000000
# mean   -13444.736081    7.579101  12.986001  -13446.224907   4.081351
# std      4289.695077    1.216851   1.787006    4290.754131   0.659628
# min    -21589.004265    5.618425  10.411238  -21591.612863   2.966651
# 25%    -16909.292510    6.584019  11.387236  -16911.065835   3.519547
# 50%    -12765.772899    7.565654  12.818688  -12771.345191   4.099583
# 75%     -9671.167886    8.773486  14.418104   -9670.865878   4.668702
# max     -7644.989848    9.391854  16.224534   -7644.315658   5.035148
#
#         beta_std  beta_entropy  gamma_mean  gamma_std  gamma_entropy
# count  40.000000     40.000000   40.000000  40.000000      40.000000
# mean    9.827114 -13443.815904    2.260765   7.306363  -13440.403603
# std     1.377829   4290.804702    0.368644   1.033423    4290.153113
# min     7.824994 -21589.206686    1.614258   5.792581  -21584.882954
# 25%     8.615703 -16908.432196    1.931661   6.403315  -16904.647938
# 50%     9.704839 -12768.787183    2.288744   7.218765  -12764.900788
# 75%    10.990847  -9668.370589    2.578749   8.185902   -9665.936215
# max    12.272353  -7642.504663    2.794283   9.115567   -7640.943026

# %%
for user in transformedData['userId'].unique():
    print transformedData[transformedData.userId == user].shape
# Out:
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)
# (9391, 16)

# %%
transformedData.to_csv('processedTransformedData.csv', index = False)

# %%
user1.shape
# Out:
# (9760, 65)
